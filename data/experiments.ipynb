# %%
from unlabeled import unlabeledDataset, TiktokenTokenizer, OpenWebTextConfig
import os

# %%
n_procs = max(1, int(os.cpu_count()*3/4))

encoder = TiktokenTokenizer()    


# for dataset in unlabeled_text_datasets: 
ds = unlabeledDataset(OpenWebTextConfig(), n_procs)
toks = ds.tokenize(encoder.tokenize_dataset, save_tokens_to_disk = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       3 encoder = TiktokenTokenizer()
#       6 # for dataset in unlabeled_text_datasets:
# ----> 7 ds = unlabeledDataset(OpenWebTextConfig(), n_procs)
#       8 toks = ds.tokenize(encoder.tokenize_dataset, save_tokens_to_disk = True)
#
# File ~/tinyUniverse/fastgpt/data/unlabeled.py:65, in unlabeledDataset.__init__(self, datasetConfig, n_proc, cache_dir, force_redownload, **kwargs)
#      60 self.force_redownload = force_redownload
#      62 if self.cache_dir is not None: self.cache_dir.mkdir(parents=True, exist_ok=True)
# ---> 65 self.dataset = datasets.load_dataset(
#      66                                     self.dataset_name,
#      67                                     num_proc=self.n_proc,
#      68                                     trust_remote_code=True,
# ...
